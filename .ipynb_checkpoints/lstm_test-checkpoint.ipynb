# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=100,out_size=1):
        super().__init__()
        self.hidden_size = hidden_size
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.linear = nn.Linear(hidden_size,out_size)
        self.hidden = (torch.zeros(1, 1, hidden_size), torch.zeros(1, 1, hidden_size))

    def forward(self,seq):
        lstm_out, self.hidden = self.lstm(seq.view(len(seq), 1, -1), self.hidden)
        pred= self.linear(lstm_out.view(len(seq), -1))

        return pred[-1]


torch.manual_seed(50)
model = LSTM()
# train_data.cuda()
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.005)


print(model)


for p in model.parameters():
    print(p.numel())
# Out:
# LSTM(
#   (lstm): LSTM(1, 100)
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )
# 400
# 40000
# 400
# 400
# 100
# 1

# %%
import random
lenth = 1000
x = []
y = []
train_data = []
for i in range(lenth):
    x.append([i*0.001+random.uniform(0,1.5)])
    y.append([i*5])
x = torch.Tensor(x)
y = torch.Tensor(y)

for i in range(lenth):
    train_data.append((x[i],y[i]))
    
# print(train_data)

# %%
for i in range(10):
    for seq,y_train in train_data:
#         print(seq,y_train)
        optimizer.zero_grad()
        model.hidden = (torch.zeros(1,1, model.hidden_size), torch.zeros(1,1, model.hidden_size))
        y_pred = model(seq)
        print(seq,y_train,y_pred)
        

        loss = criterion(y_pred, y_train)
        print(loss)
        print('.......................')
        loss.backward()
        optimizer.step()
    print(loss)
# Out:
# tensor([0.7489]) tensor([0.]) tensor([4500.2158], grad_fn=<SelectBackward>)
# tensor(20251942., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8964]) tensor([5.]) tensor([4455.2139], grad_fn=<SelectBackward>)
# tensor(19804404., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8645]) tensor([10.]) tensor([4410.7119], grad_fn=<SelectBackward>)
# tensor(19366266., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3047]) tensor([15.]) tensor([4366.7046], grad_fn=<SelectBackward>)
# tensor(18937332., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1345]) tensor([20.]) tensor([4323.1875], grad_fn=<SelectBackward>)
# tensor(18517422., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9104]) tensor([25.]) tensor([4280.1558], grad_fn=<SelectBackward>)
# tensor(18106350., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3300]) tensor([30.]) tensor([4237.6040], grad_fn=<SelectBackward>)
# tensor(17703932., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6455]) tensor([35.]) tensor([4195.5278], grad_fn=<SelectBackward>)
# tensor(17309992., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0671]) tensor([40.]) tensor([4153.9224], grad_fn=<SelectBackward>)
# tensor(16924358., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5515]) tensor([45.]) tensor([4112.7832], grad_fn=<SelectBackward>)
# tensor(16546860., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4749]) tensor([50.]) tensor([4072.1055], grad_fn=<SelectBackward>)
# tensor(16177332., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9210]) tensor([55.]) tensor([4031.8845], grad_fn=<SelectBackward>)
# tensor(15815610., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5253]) tensor([60.]) tensor([3992.1157], grad_fn=<SelectBackward>)
# tensor(15461534., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1938]) tensor([65.]) tensor([3952.7947], grad_fn=<SelectBackward>)
# tensor(15114947., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4758]) tensor([70.]) tensor([3913.9167], grad_fn=<SelectBackward>)
# tensor(14775696., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4773]) tensor([75.]) tensor([3875.4775], grad_fn=<SelectBackward>)
# tensor(14443630., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2424]) tensor([80.]) tensor([3837.4727], grad_fn=<SelectBackward>)
# tensor(14118601., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8082]) tensor([85.]) tensor([3799.8979], grad_fn=<SelectBackward>)
# tensor(13800467., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2259]) tensor([90.]) tensor([3762.7490], grad_fn=<SelectBackward>)
# tensor(13489085., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3866]) tensor([95.]) tensor([3726.0215], grad_fn=<SelectBackward>)
# tensor(13184317., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2308]) tensor([100.]) tensor([3689.7112], grad_fn=<SelectBackward>)
# tensor(12886026., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0691]) tensor([105.]) tensor([3653.8140], grad_fn=<SelectBackward>)
# tensor(12594081., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2826]) tensor([110.]) tensor([3618.3259], grad_fn=<SelectBackward>)
# tensor(12308351., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0503]) tensor([115.]) tensor([3583.2427], grad_fn=<SelectBackward>)
# tensor(12028707., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1324]) tensor([120.]) tensor([3548.5603], grad_fn=<SelectBackward>)
# tensor(11755026., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2359]) tensor([125.]) tensor([3514.2747], grad_fn=<SelectBackward>)
# tensor(11487183., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2948]) tensor([130.]) tensor([3480.3818], grad_fn=<SelectBackward>)
# tensor(11225058., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6294]) tensor([135.]) tensor([3446.8779], grad_fn=<SelectBackward>)
# tensor(10968535., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.0654]) tensor([140.]) tensor([3413.7590], grad_fn=<SelectBackward>)
# tensor(10717498., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4324]) tensor([145.]) tensor([3381.0215], grad_fn=<SelectBackward>)
# tensor(10471835., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5258]) tensor([150.]) tensor([3348.6614], grad_fn=<SelectBackward>)
# tensor(10231435., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0793]) tensor([155.]) tensor([3316.6748], grad_fn=<SelectBackward>)
# tensor(9996188., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9650]) tensor([160.]) tensor([3285.0581], grad_fn=<SelectBackward>)
# tensor(9765988., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4631]) tensor([165.]) tensor([3253.8076], grad_fn=<SelectBackward>)
# tensor(9540732., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3360]) tensor([170.]) tensor([3222.9194], grad_fn=<SelectBackward>)
# tensor(9320317., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4476]) tensor([175.]) tensor([3192.3901], grad_fn=<SelectBackward>)
# tensor(9104643., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1038]) tensor([180.]) tensor([3162.2163], grad_fn=<SelectBackward>)
# tensor(8893614., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0635]) tensor([185.]) tensor([3132.3940], grad_fn=<SelectBackward>)
# tensor(8687132., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7981]) tensor([190.]) tensor([3102.9202], grad_fn=<SelectBackward>)
# tensor(8485104., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5547]) tensor([195.]) tensor([3073.7910], grad_fn=<SelectBackward>)
# tensor(8287437.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3582]) tensor([200.]) tensor([3045.0032], grad_fn=<SelectBackward>)
# tensor(8094043., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4381]) tensor([205.]) tensor([3016.5532], grad_fn=<SelectBackward>)
# tensor(7904831.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1493]) tensor([210.]) tensor([2988.4377], grad_fn=<SelectBackward>)
# tensor(7719716.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6592]) tensor([215.]) tensor([2960.6533], grad_fn=<SelectBackward>)
# tensor(7538612., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9687]) tensor([220.]) tensor([2933.1968], grad_fn=<SelectBackward>)
# tensor(7361437., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3879]) tensor([225.]) tensor([2906.0647], grad_fn=<SelectBackward>)
# tensor(7188108., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3448]) tensor([230.]) tensor([2879.2542], grad_fn=<SelectBackward>)
# tensor(7018547.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3269]) tensor([235.]) tensor([2852.7617], grad_fn=<SelectBackward>)
# tensor(6852676.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1560]) tensor([240.]) tensor([2826.5840], grad_fn=<SelectBackward>)
# tensor(6690416.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1758]) tensor([245.]) tensor([2800.7183], grad_fn=<SelectBackward>)
# tensor(6531696., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1218]) tensor([250.]) tensor([2775.1611], grad_fn=<SelectBackward>)
# tensor(6376438.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2403]) tensor([255.]) tensor([2749.9094], grad_fn=<SelectBackward>)
# tensor(6224573., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1930]) tensor([260.]) tensor([2724.9604], grad_fn=<SelectBackward>)
# tensor(6076030., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9395]) tensor([265.]) tensor([2700.3108], grad_fn=<SelectBackward>)
# tensor(5930738.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4096]) tensor([270.]) tensor([2675.9578], grad_fn=<SelectBackward>)
# tensor(5788633., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9192]) tensor([275.]) tensor([2651.8982], grad_fn=<SelectBackward>)
# tensor(5649645., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8421]) tensor([280.]) tensor([2628.1292], grad_fn=<SelectBackward>)
# tensor(5513710.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5174]) tensor([285.]) tensor([2604.6479], grad_fn=<SelectBackward>)
# tensor(5380766.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3916]) tensor([290.]) tensor([2581.4514], grad_fn=<SelectBackward>)
# tensor(5250749.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3113]) tensor([295.]) tensor([2558.5369], grad_fn=<SelectBackward>)
# tensor(5123599., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7312]) tensor([300.]) tensor([2535.9016], grad_fn=<SelectBackward>)
# tensor(4999256., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1198]) tensor([305.]) tensor([2513.5425], grad_fn=<SelectBackward>)
# tensor(4877660., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5439]) tensor([310.]) tensor([2491.4570], grad_fn=<SelectBackward>)
# tensor(4758755., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2056]) tensor([315.]) tensor([2469.6426], grad_fn=<SelectBackward>)
# tensor(4642484.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6974]) tensor([320.]) tensor([2448.0962], grad_fn=<SelectBackward>)
# tensor(4528793.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0603]) tensor([325.]) tensor([2426.8152], grad_fn=<SelectBackward>)
# tensor(4417627., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4165]) tensor([330.]) tensor([2405.7971], grad_fn=<SelectBackward>)
# tensor(4308933.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7769]) tensor([335.]) tensor([2385.0391], grad_fn=<SelectBackward>)
# tensor(4202660., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2937]) tensor([340.]) tensor([2364.5386], grad_fn=<SelectBackward>)
# tensor(4098756.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5214]) tensor([345.]) tensor([2344.2932], grad_fn=<SelectBackward>)
# tensor(3997173.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2135]) tensor([350.]) tensor([2324.3003], grad_fn=<SelectBackward>)
# tensor(3897861.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3809]) tensor([355.]) tensor([2304.5574], grad_fn=<SelectBackward>)
# tensor(3800774., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1126]) tensor([360.]) tensor([2285.0618], grad_fn=<SelectBackward>)
# tensor(3705862.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1874]) tensor([365.]) tensor([2265.8110], grad_fn=<SelectBackward>)
# tensor(3613082.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7119]) tensor([370.]) tensor([2246.8030], grad_fn=<SelectBackward>)
# tensor(3522389.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6442]) tensor([375.]) tensor([2228.0349], grad_fn=<SelectBackward>)
# tensor(3433738.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3066]) tensor([380.]) tensor([2209.5046], grad_fn=<SelectBackward>)
# tensor(3347087.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.0798]) tensor([385.]) tensor([2191.2095], grad_fn=<SelectBackward>)
# tensor(3262392.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7496]) tensor([390.]) tensor([2173.1475], grad_fn=<SelectBackward>)
# tensor(3179614.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8816]) tensor([395.]) tensor([2155.3159], grad_fn=<SelectBackward>)
# tensor(3098712.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4706]) tensor([400.]) tensor([2137.7126], grad_fn=<SelectBackward>)
# tensor(3019645.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.0847]) tensor([405.]) tensor([2120.3354], grad_fn=<SelectBackward>)
# tensor(2942375.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2775]) tensor([410.]) tensor([2103.1821], grad_fn=<SelectBackward>)
# tensor(2866865.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2875]) tensor([415.]) tensor([2086.2502], grad_fn=<SelectBackward>)
# tensor(2793077.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0805]) tensor([420.]) tensor([2069.5378], grad_fn=<SelectBackward>)
# tensor(2720975., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3511]) tensor([425.]) tensor([2053.0425], grad_fn=<SelectBackward>)
# tensor(2650522.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4534]) tensor([430.]) tensor([2036.7621], grad_fn=<SelectBackward>)
# tensor(2581684.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1653]) tensor([435.]) tensor([2020.6945], grad_fn=<SelectBackward>)
# tensor(2514427., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2405]) tensor([440.]) tensor([2004.8375], grad_fn=<SelectBackward>)
# tensor(2448716.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4458]) tensor([445.]) tensor([1989.1892], grad_fn=<SelectBackward>)
# tensor(2384520.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7984]) tensor([450.]) tensor([1973.7473], grad_fn=<SelectBackward>)
# tensor(2321806., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1929]) tensor([455.]) tensor([1958.5099], grad_fn=<SelectBackward>)
# tensor(2260542., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3863]) tensor([460.]) tensor([1943.4747], grad_fn=<SelectBackward>)
# tensor(2200697.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5273]) tensor([465.]) tensor([1928.6400], grad_fn=<SelectBackward>)
# tensor(2142242., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4496]) tensor([470.]) tensor([1914.0037], grad_fn=<SelectBackward>)
# tensor(2085146.6250, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4582]) tensor([475.]) tensor([1899.5636], grad_fn=<SelectBackward>)
# tensor(2029381.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7200]) tensor([480.]) tensor([1885.3180], grad_fn=<SelectBackward>)
# tensor(1974918.6250, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2321]) tensor([485.]) tensor([1871.2648], grad_fn=<SelectBackward>)
# tensor(1921730., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3553]) tensor([490.]) tensor([1857.4021], grad_fn=<SelectBackward>)
# tensor(1869788.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1868]) tensor([495.]) tensor([1843.7280], grad_fn=<SelectBackward>)
# tensor(1819067.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3794]) tensor([500.]) tensor([1830.2407], grad_fn=<SelectBackward>)
# tensor(1769540.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0604]) tensor([505.]) tensor([1816.9384], grad_fn=<SelectBackward>)
# tensor(1721182.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5047]) tensor([510.]) tensor([1803.8190], grad_fn=<SelectBackward>)
# tensor(1673967.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5504]) tensor([515.]) tensor([1790.8807], grad_fn=<SelectBackward>)
# tensor(1627871.6250, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3425]) tensor([520.]) tensor([1778.1219], grad_fn=<SelectBackward>)
# tensor(1582870.8750, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5060]) tensor([525.]) tensor([1765.5408], grad_fn=<SelectBackward>)
# tensor(1538941.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5892]) tensor([530.]) tensor([1753.1354], grad_fn=<SelectBackward>)
# tensor(1496060.1250, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4276]) tensor([535.]) tensor([1740.9041], grad_fn=<SelectBackward>)
# tensor(1454204.6250, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2113]) tensor([540.]) tensor([1728.8450], grad_fn=<SelectBackward>)
# tensor(1413352.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7673]) tensor([545.]) tensor([1716.9565], grad_fn=<SelectBackward>)
# tensor(1373482.1250, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2021]) tensor([550.]) tensor([1705.2369], grad_fn=<SelectBackward>)
# tensor(1334572.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5127]) tensor([555.]) tensor([1693.6846], grad_fn=<SelectBackward>)
# tensor(1296602.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9816]) tensor([560.]) tensor([1682.2977], grad_fn=<SelectBackward>)
# tensor(1259552.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6544]) tensor([565.]) tensor([1671.0747], grad_fn=<SelectBackward>)
# tensor(1223401.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9685]) tensor([570.]) tensor([1660.0139], grad_fn=<SelectBackward>)
# tensor(1188130.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4892]) tensor([575.]) tensor([1649.1138], grad_fn=<SelectBackward>)
# tensor(1153720.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3675]) tensor([580.]) tensor([1638.3727], grad_fn=<SelectBackward>)
# tensor(1120152.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8975]) tensor([585.]) tensor([1627.7889], grad_fn=<SelectBackward>)
# tensor(1087408.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1825]) tensor([590.]) tensor([1617.3611], grad_fn=<SelectBackward>)
# tensor(1055470.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4285]) tensor([595.]) tensor([1607.0875], grad_fn=<SelectBackward>)
# tensor(1024321.1875, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2958]) tensor([600.]) tensor([1596.9667], grad_fn=<SelectBackward>)
# tensor(993942.5625, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5606]) tensor([605.]) tensor([1586.9969], grad_fn=<SelectBackward>)
# tensor(964318., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6735]) tensor([610.]) tensor([1577.1770], grad_fn=<SelectBackward>)
# tensor(935431.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3725]) tensor([615.]) tensor([1567.5052], grad_fn=<SelectBackward>)
# tensor(907266.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2125]) tensor([620.]) tensor([1557.9802], grad_fn=<SelectBackward>)
# tensor(879806.8750, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3570]) tensor([625.]) tensor([1548.6005], grad_fn=<SelectBackward>)
# tensor(853037.8125, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5599]) tensor([630.]) tensor([1539.3645], grad_fn=<SelectBackward>)
# tensor(826943.8125, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5324]) tensor([635.]) tensor([1530.2709], grad_fn=<SelectBackward>)
# tensor(801509.9375, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5248]) tensor([640.]) tensor([1521.3181], grad_fn=<SelectBackward>)
# tensor(776721.6250, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7730]) tensor([645.]) tensor([1512.5049], grad_fn=<SelectBackward>)
# tensor(752564.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4954]) tensor([650.]) tensor([1503.8298], grad_fn=<SelectBackward>)
# tensor(729025.3750, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2348]) tensor([655.]) tensor([1495.2915], grad_fn=<SelectBackward>)
# tensor(706089.8125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2064]) tensor([660.]) tensor([1486.8885], grad_fn=<SelectBackward>)
# tensor(683744.6875, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2241]) tensor([665.]) tensor([1478.6196], grad_fn=<SelectBackward>)
# tensor(661976.8750, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4029]) tensor([670.]) tensor([1470.4834], grad_fn=<SelectBackward>)
# tensor(640773.6875, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3787]) tensor([675.]) tensor([1462.4785], grad_fn=<SelectBackward>)
# tensor(620122.4375, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5950]) tensor([680.]) tensor([1454.6038], grad_fn=<SelectBackward>)
# tensor(600011., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2217]) tensor([685.]) tensor([1446.8577], grad_fn=<SelectBackward>)
# tensor(580427.1250, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7940]) tensor([690.]) tensor([1439.2391], grad_fn=<SelectBackward>)
# tensor(561359.3125, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9500]) tensor([695.]) tensor([1431.7467], grad_fn=<SelectBackward>)
# tensor(542795.6875, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6208]) tensor([700.]) tensor([1424.3793], grad_fn=<SelectBackward>)
# tensor(524725.3125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1111]) tensor([705.]) tensor([1417.1355], grad_fn=<SelectBackward>)
# tensor(507136.9688, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5020]) tensor([710.]) tensor([1410.0142], grad_fn=<SelectBackward>)
# tensor(490019.8125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1047]) tensor([715.]) tensor([1403.0140], grad_fn=<SelectBackward>)
# tensor(473363.3125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3325]) tensor([720.]) tensor([1396.1339], grad_fn=<SelectBackward>)
# tensor(457157.0625, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5564]) tensor([725.]) tensor([1389.3726], grad_fn=<SelectBackward>)
# tensor(441390.9062, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3132]) tensor([730.]) tensor([1382.7289], grad_fn=<SelectBackward>)
# tensor(426055., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6307]) tensor([735.]) tensor([1376.2015], grad_fn=<SelectBackward>)
# tensor(411139.4062, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7481]) tensor([740.]) tensor([1369.7896], grad_fn=<SelectBackward>)
# tensor(396634.8750, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4489]) tensor([745.]) tensor([1363.4917], grad_fn=<SelectBackward>)
# tensor(382531.9688, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9136]) tensor([750.]) tensor([1357.3068], grad_fn=<SelectBackward>)
# tensor(368821.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0111]) tensor([755.]) tensor([1351.2336], grad_fn=<SelectBackward>)
# tensor(355494.5625, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0275]) tensor([760.]) tensor([1345.2714], grad_fn=<SelectBackward>)
# tensor(342542.5625, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9901]) tensor([765.]) tensor([1339.4187], grad_fn=<SelectBackward>)
# tensor(329956.8438, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7439]) tensor([770.]) tensor([1333.6746], grad_fn=<SelectBackward>)
# tensor(317729., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4210]) tensor([775.]) tensor([1328.0378], grad_fn=<SelectBackward>)
# tensor(305850.8438, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5768]) tensor([780.]) tensor([1322.5074], grad_fn=<SelectBackward>)
# tensor(294314.3438, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5466]) tensor([785.]) tensor([1317.0824], grad_fn=<SelectBackward>)
# tensor(283111.6875, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9534]) tensor([790.]) tensor([1311.7616], grad_fn=<SelectBackward>)
# tensor(272235.1562, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0476]) tensor([795.]) tensor([1306.5439], grad_fn=<SelectBackward>)
# tensor(261677.2031, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0835]) tensor([800.]) tensor([1301.4285], grad_fn=<SelectBackward>)
# tensor(251430.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5399]) tensor([805.]) tensor([1296.4142], grad_fn=<SelectBackward>)
# tensor(241487.9062, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5913]) tensor([810.]) tensor([1291.5000], grad_fn=<SelectBackward>)
# tensor(231842.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2406]) tensor([815.]) tensor([1286.6851], grad_fn=<SelectBackward>)
# tensor(222486.7969, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4658]) tensor([820.]) tensor([1281.9683], grad_fn=<SelectBackward>)
# tensor(213414.6719, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1325]) tensor([825.]) tensor([1277.3486], grad_fn=<SelectBackward>)
# tensor(204619.2812, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4898]) tensor([830.]) tensor([1272.8252], grad_fn=<SelectBackward>)
# tensor(196094.1562, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9687]) tensor([835.]) tensor([1268.3970], grad_fn=<SelectBackward>)
# tensor(187832.9375, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4785]) tensor([840.]) tensor([1264.0630], grad_fn=<SelectBackward>)
# tensor(179829.4219, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0092]) tensor([845.]) tensor([1259.8224], grad_fn=<SelectBackward>)
# tensor(172077.6094, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9254]) tensor([850.]) tensor([1255.6742], grad_fn=<SelectBackward>)
# tensor(164571.5469, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5460]) tensor([855.]) tensor([1251.6174], grad_fn=<SelectBackward>)
# tensor(157305.3906, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4659]) tensor([860.]) tensor([1247.6512], grad_fn=<SelectBackward>)
# tensor(150273.4844, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1897]) tensor([865.]) tensor([1243.7748], grad_fn=<SelectBackward>)
# tensor(143470.3281, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5346]) tensor([870.]) tensor([1239.9871], grad_fn=<SelectBackward>)
# tensor(136890.4219, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3038]) tensor([875.]) tensor([1236.2872], grad_fn=<SelectBackward>)
# tensor(130528.4609, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5200]) tensor([880.]) tensor([1232.6743], grad_fn=<SelectBackward>)
# tensor(124379.1719, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3118]) tensor([885.]) tensor([1229.1476], grad_fn=<SelectBackward>)
# tensor(118437.5625, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5239]) tensor([890.]) tensor([1225.7061], grad_fn=<SelectBackward>)
# tensor(112698.5547, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2550]) tensor([895.]) tensor([1222.3490], grad_fn=<SelectBackward>)
# tensor(107157.3672, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5848]) tensor([900.]) tensor([1219.0756], grad_fn=<SelectBackward>)
# tensor(101809.2109, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.1811]) tensor([905.]) tensor([1215.8848], grad_fn=<SelectBackward>)
# tensor(96649.3359, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2105]) tensor([910.]) tensor([1212.7759], grad_fn=<SelectBackward>)
# tensor(91673.2344, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8302]) tensor([915.]) tensor([1209.7482], grad_fn=<SelectBackward>)
# tensor(86876.4844, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5657]) tensor([920.]) tensor([1206.8007], grad_fn=<SelectBackward>)
# tensor(82254.6172, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9548]) tensor([925.]) tensor([1203.9326], grad_fn=<SelectBackward>)
# tensor(77803.4062, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3867]) tensor([930.]) tensor([1201.1433], grad_fn=<SelectBackward>)
# tensor(73518.6953, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9440]) tensor([935.]) tensor([1198.4319], grad_fn=<SelectBackward>)
# tensor(69396.3594, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1726]) tensor([940.]) tensor([1195.7976], grad_fn=<SelectBackward>)
# tensor(65432.4141, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3620]) tensor([945.]) tensor([1193.2396], grad_fn=<SelectBackward>)
# tensor(61622.9102, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2305]) tensor([950.]) tensor([1190.7572], grad_fn=<SelectBackward>)
# tensor(57964.0312, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6552]) tensor([955.]) tensor([1188.3496], grad_fn=<SelectBackward>)
# tensor(54452.0391, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7838]) tensor([960.]) tensor([1186.0161], grad_fn=<SelectBackward>)
# tensor(51083.2852, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7684]) tensor([965.]) tensor([1183.7560], grad_fn=<SelectBackward>)
# tensor(47854.1797, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4344]) tensor([970.]) tensor([1181.5685], grad_fn=<SelectBackward>)
# tensor(44761.2227, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6984]) tensor([975.]) tensor([1179.4528], grad_fn=<SelectBackward>)
# tensor(41800.9297, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4902]) tensor([980.]) tensor([1177.4082], grad_fn=<SelectBackward>)
# tensor(38970., grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9356]) tensor([985.]) tensor([1175.4341], grad_fn=<SelectBackward>)
# tensor(36265.1406, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5762]) tensor([990.]) tensor([1173.5298], grad_fn=<SelectBackward>)
# tensor(33683.1836, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1010]) tensor([995.]) tensor([1171.6945], grad_fn=<SelectBackward>)
# tensor(31220.9316, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3501]) tensor([1000.]) tensor([1169.9275], grad_fn=<SelectBackward>)
# tensor(28875.3516, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6710]) tensor([1005.]) tensor([1168.2283], grad_fn=<SelectBackward>)
# tensor(26643.4688, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6666]) tensor([1010.]) tensor([1166.5959], grad_fn=<SelectBackward>)
# tensor(24522.2910, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3556]) tensor([1015.]) tensor([1165.0300], grad_fn=<SelectBackward>)
# tensor(22509.0098, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2903]) tensor([1020.]) tensor([1163.5298], grad_fn=<SelectBackward>)
# tensor(20600.7988, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2820]) tensor([1025.]) tensor([1162.0945], grad_fn=<SelectBackward>)
# tensor(18794.8965, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5225]) tensor([1030.]) tensor([1160.7235], grad_fn=<SelectBackward>)
# tensor(17088.6367, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4564]) tensor([1035.]) tensor([1159.4163], grad_fn=<SelectBackward>)
# tensor(15479.4053, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6076]) tensor([1040.]) tensor([1158.1721], grad_fn=<SelectBackward>)
# tensor(13964.6494, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5443]) tensor([1045.]) tensor([1156.9904], grad_fn=<SelectBackward>)
# tensor(12541.8398, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6957]) tensor([1050.]) tensor([1155.8705], grad_fn=<SelectBackward>)
# tensor(11208.5596, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9599]) tensor([1055.]) tensor([1154.8118], grad_fn=<SelectBackward>)
# tensor(9962.3887, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7278]) tensor([1060.]) tensor([1153.8136], grad_fn=<SelectBackward>)
# tensor(8800.9912, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4093]) tensor([1065.]) tensor([1152.8755], grad_fn=<SelectBackward>)
# tensor(7722.1016, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1513]) tensor([1070.]) tensor([1151.9967], grad_fn=<SelectBackward>)
# tensor(6723.4595, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7671]) tensor([1075.]) tensor([1151.1768], grad_fn=<SelectBackward>)
# tensor(5802.8984, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4942]) tensor([1080.]) tensor([1150.4150], grad_fn=<SelectBackward>)
# tensor(4958.2778, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3762]) tensor([1085.]) tensor([1149.7109], grad_fn=<SelectBackward>)
# tensor(4187.5054, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2484]) tensor([1090.]) tensor([1149.0638], grad_fn=<SelectBackward>)
# tensor(3488.5376, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1846]) tensor([1095.]) tensor([1148.4731], grad_fn=<SelectBackward>)
# tensor(2859.3772, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5275]) tensor([1100.]) tensor([1147.9384], grad_fn=<SelectBackward>)
# tensor(2298.0859, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6242]) tensor([1105.]) tensor([1147.4590], grad_fn=<SelectBackward>)
# tensor(1802.7654, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4774]) tensor([1110.]) tensor([1147.0344], grad_fn=<SelectBackward>)
# tensor(1371.5486, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5665]) tensor([1115.]) tensor([1146.6641], grad_fn=<SelectBackward>)
# tensor(1002.6129, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0456]) tensor([1120.]) tensor([1146.3474], grad_fn=<SelectBackward>)
# tensor(694.1861, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0593]) tensor([1125.]) tensor([1146.0840], grad_fn=<SelectBackward>)
# tensor(444.5344, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6115]) tensor([1130.]) tensor([1145.8732], grad_fn=<SelectBackward>)
# tensor(251.9575, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3118]) tensor([1135.]) tensor([1145.7145], grad_fn=<SelectBackward>)
# tensor(114.8000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1209]) tensor([1140.]) tensor([1145.6073], grad_fn=<SelectBackward>)
# tensor(31.4418, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7356]) tensor([1145.]) tensor([1145.5513], grad_fn=<SelectBackward>)
# tensor(0.3039, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5559]) tensor([1150.]) tensor([1145.5458], grad_fn=<SelectBackward>)
# tensor(19.8401, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7878]) tensor([1155.]) tensor([1145.5903], grad_fn=<SelectBackward>)
# tensor(88.5419, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6311]) tensor([1160.]) tensor([1145.6844], grad_fn=<SelectBackward>)
# tensor(204.9350, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9396]) tensor([1165.]) tensor([1145.8276], grad_fn=<SelectBackward>)
# tensor(367.5795, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7288]) tensor([1170.]) tensor([1146.0194], grad_fn=<SelectBackward>)
# tensor(575.0687, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2805]) tensor([1175.]) tensor([1146.2592], grad_fn=<SelectBackward>)
# tensor(826.0361, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1211]) tensor([1180.]) tensor([1146.5465], grad_fn=<SelectBackward>)
# tensor(1119.1361, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5310]) tensor([1185.]) tensor([1146.8811], grad_fn=<SelectBackward>)
# tensor(1453.0503, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6428]) tensor([1190.]) tensor([1147.2623], grad_fn=<SelectBackward>)
# tensor(1826.5085, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8207]) tensor([1195.]) tensor([1147.6897], grad_fn=<SelectBackward>)
# tensor(2238.2646, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5836]) tensor([1200.]) tensor([1148.1628], grad_fn=<SelectBackward>)
# tensor(2687.0911, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2534]) tensor([1205.]) tensor([1148.6812], grad_fn=<SelectBackward>)
# tensor(3171.8125, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5207]) tensor([1210.]) tensor([1149.2444], grad_fn=<SelectBackward>)
# tensor(3691.2449, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0934]) tensor([1215.]) tensor([1149.8519], grad_fn=<SelectBackward>)
# tensor(4244.2710, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6050]) tensor([1220.]) tensor([1150.5034], grad_fn=<SelectBackward>)
# tensor(4829.7749, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5824]) tensor([1225.]) tensor([1151.1984], grad_fn=<SelectBackward>)
# tensor(5446.6816, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6035]) tensor([1230.]) tensor([1151.9364], grad_fn=<SelectBackward>)
# tensor(6093.9253, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2233]) tensor([1235.]) tensor([1152.7170], grad_fn=<SelectBackward>)
# tensor(6770.4854, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2187]) tensor([1240.]) tensor([1153.5399], grad_fn=<SelectBackward>)
# tensor(7475.3462, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8457]) tensor([1245.]) tensor([1154.4045], grad_fn=<SelectBackward>)
# tensor(8207.5371, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6549]) tensor([1250.]) tensor([1155.3105], grad_fn=<SelectBackward>)
# tensor(8966.0928, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7369]) tensor([1255.]) tensor([1156.2574], grad_fn=<SelectBackward>)
# tensor(9750.0918, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4750]) tensor([1260.]) tensor([1157.2449], grad_fn=<SelectBackward>)
# tensor(10558.6162, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4799]) tensor([1265.]) tensor([1158.2725], grad_fn=<SelectBackward>)
# tensor(11390.7676, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5119]) tensor([1270.]) tensor([1159.3397], grad_fn=<SelectBackward>)
# tensor(12245.6973, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7487]) tensor([1275.]) tensor([1160.4463], grad_fn=<SelectBackward>)
# tensor(13122.5527, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3284]) tensor([1280.]) tensor([1161.5918], grad_fn=<SelectBackward>)
# tensor(14020.5029, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3892]) tensor([1285.]) tensor([1162.7759], grad_fn=<SelectBackward>)
# tensor(14938.7354, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7386]) tensor([1290.]) tensor([1163.9982], grad_fn=<SelectBackward>)
# tensor(15876.4619, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4146]) tensor([1295.]) tensor([1165.2582], grad_fn=<SelectBackward>)
# tensor(16832.9395, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9982]) tensor([1300.]) tensor([1166.5555], grad_fn=<SelectBackward>)
# tensor(17807.4238, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3875]) tensor([1305.]) tensor([1167.8900], grad_fn=<SelectBackward>)
# tensor(18799.1484, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5143]) tensor([1310.]) tensor([1169.2611], grad_fn=<SelectBackward>)
# tensor(19807.4355, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9222]) tensor([1315.]) tensor([1170.6685], grad_fn=<SelectBackward>)
# tensor(20831.5938, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5604]) tensor([1320.]) tensor([1172.1118], grad_fn=<SelectBackward>)
# tensor(21870.9141, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6289]) tensor([1325.]) tensor([1173.5907], grad_fn=<SelectBackward>)
# tensor(22924.7773, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9018]) tensor([1330.]) tensor([1175.1047], grad_fn=<SelectBackward>)
# tensor(23992.5430, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7050]) tensor([1335.]) tensor([1176.6537], grad_fn=<SelectBackward>)
# tensor(25073.5547, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1415]) tensor([1340.]) tensor([1178.2372], grad_fn=<SelectBackward>)
# tensor(26167.2090, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6658]) tensor([1345.]) tensor([1179.8549], grad_fn=<SelectBackward>)
# tensor(27272.9180, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7081]) tensor([1350.]) tensor([1181.5063], grad_fn=<SelectBackward>)
# tensor(28390.1113, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3927]) tensor([1355.]) tensor([1183.1913], grad_fn=<SelectBackward>)
# tensor(29518.2344, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6235]) tensor([1360.]) tensor([1184.9094], grad_fn=<SelectBackward>)
# tensor(30656.7090, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6149]) tensor([1365.]) tensor([1186.6603], grad_fn=<SelectBackward>)
# tensor(31805.0566, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1706]) tensor([1370.]) tensor([1188.4437], grad_fn=<SelectBackward>)
# tensor(32962.6797, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7475]) tensor([1375.]) tensor([1190.2593], grad_fn=<SelectBackward>)
# tensor(34129.1328, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8213]) tensor([1380.]) tensor([1192.1067], grad_fn=<SelectBackward>)
# tensor(35303.8945, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4801]) tensor([1385.]) tensor([1193.9856], grad_fn=<SelectBackward>)
# tensor(36486.5039, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7307]) tensor([1390.]) tensor([1195.8958], grad_fn=<SelectBackward>)
# tensor(37676.4609, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4396]) tensor([1395.]) tensor([1197.8368], grad_fn=<SelectBackward>)
# tensor(38873.3320, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4923]) tensor([1400.]) tensor([1199.8085], grad_fn=<SelectBackward>)
# tensor(40076.6484, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4090]) tensor([1405.]) tensor([1201.8104], grad_fn=<SelectBackward>)
# tensor(41286.0039, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1708]) tensor([1410.]) tensor([1203.8423], grad_fn=<SelectBackward>)
# tensor(42501.0039, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0522]) tensor([1415.]) tensor([1205.9038], grad_fn=<SelectBackward>)
# tensor(43721.2188, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4736]) tensor([1420.]) tensor([1207.9948], grad_fn=<SelectBackward>)
# tensor(44946.2266, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4573]) tensor([1425.]) tensor([1210.1147], grad_fn=<SelectBackward>)
# tensor(46175.6719, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3781]) tensor([1430.]) tensor([1212.2635], grad_fn=<SelectBackward>)
# tensor(47409.1602, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5988]) tensor([1435.]) tensor([1214.4409], grad_fn=<SelectBackward>)
# tensor(48646.3086, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5635]) tensor([1440.]) tensor([1216.6465], grad_fn=<SelectBackward>)
# tensor(49886.7930, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4366]) tensor([1445.]) tensor([1218.8800], grad_fn=<SelectBackward>)
# tensor(51130.2539, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5618]) tensor([1450.]) tensor([1221.1412], grad_fn=<SelectBackward>)
# tensor(52376.3359, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4890]) tensor([1455.]) tensor([1223.4298], grad_fn=<SelectBackward>)
# tensor(53624.7539, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6410]) tensor([1460.]) tensor([1225.7455], grad_fn=<SelectBackward>)
# tensor(54875.1797, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.2989]) tensor([1465.]) tensor([1228.0880], grad_fn=<SelectBackward>)
# tensor(56127.2891, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2323]) tensor([1470.]) tensor([1230.4572], grad_fn=<SelectBackward>)
# tensor(57380.7773, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4932]) tensor([1475.]) tensor([1232.8525], grad_fn=<SelectBackward>)
# tensor(58635.3945, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6456]) tensor([1480.]) tensor([1235.2740], grad_fn=<SelectBackward>)
# tensor(59890.7930, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6119]) tensor([1485.]) tensor([1237.7213], grad_fn=<SelectBackward>)
# tensor(61146.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.8835]) tensor([1490.]) tensor([1240.1941], grad_fn=<SelectBackward>)
# tensor(62402.9922, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5216]) tensor([1495.]) tensor([1242.6921], grad_fn=<SelectBackward>)
# tensor(63659.2578, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7333]) tensor([1500.]) tensor([1245.2152], grad_fn=<SelectBackward>)
# tensor(64915.2891, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1373]) tensor([1505.]) tensor([1247.7631], grad_fn=<SelectBackward>)
# tensor(66170.8438, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5179]) tensor([1510.]) tensor([1250.3354], grad_fn=<SelectBackward>)
# tensor(67425.6797, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.3222]) tensor([1515.]) tensor([1252.9321], grad_fn=<SelectBackward>)
# tensor(68679.5703, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4798]) tensor([1520.]) tensor([1255.5529], grad_fn=<SelectBackward>)
# tensor(69932.2891, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3497]) tensor([1525.]) tensor([1258.1974], grad_fn=<SelectBackward>)
# tensor(71183.6328, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9121]) tensor([1530.]) tensor([1260.8654], grad_fn=<SelectBackward>)
# tensor(72433.4531, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4015]) tensor([1535.]) tensor([1263.5568], grad_fn=<SelectBackward>)
# tensor(73681.4297, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0082]) tensor([1540.]) tensor([1266.2712], grad_fn=<SelectBackward>)
# tensor(74927.4375, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4714]) tensor([1545.]) tensor([1269.0085], grad_fn=<SelectBackward>)
# tensor(76171.2812, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4637]) tensor([1550.]) tensor([1271.7684], grad_fn=<SelectBackward>)
# tensor(77412.8047, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7460]) tensor([1555.]) tensor([1274.5508], grad_fn=<SelectBackward>)
# tensor(78651.7656, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.6905]) tensor([1560.]) tensor([1277.3552], grad_fn=<SelectBackward>)
# tensor(79888.0703, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.7679]) tensor([1565.]) tensor([1280.1816], grad_fn=<SelectBackward>)
# tensor(81121.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1296]) tensor([1570.]) tensor([1283.0298], grad_fn=<SelectBackward>)
# tensor(82351.9062, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9896]) tensor([1575.]) tensor([1285.8995], grad_fn=<SelectBackward>)
# tensor(83579.0781, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3326]) tensor([1580.]) tensor([1288.7905], grad_fn=<SelectBackward>)
# tensor(84802.9531, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.5478]) tensor([1585.]) tensor([1291.7026], grad_fn=<SelectBackward>)
# tensor(86023.3438, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2458]) tensor([1590.]) tensor([1294.6356], grad_fn=<SelectBackward>)
# tensor(87240.1172, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1010]) tensor([1595.]) tensor([1297.5892], grad_fn=<SelectBackward>)
# tensor(88453.1641, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.4818]) tensor([1600.]) tensor([1300.5634], grad_fn=<SelectBackward>)
# tensor(89662.3047, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2120]) tensor([1605.]) tensor([1303.5577], grad_fn=<SelectBackward>)
# tensor(90867.4375, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6505]) tensor([1610.]) tensor([1306.5721], grad_fn=<SelectBackward>)
# tensor(92068.4609, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9208]) tensor([1615.]) tensor([1309.6064], grad_fn=<SelectBackward>)
# ...
# .......................
# tensor([1.4024]) tensor([4470.]) tensor([3970.6262], grad_fn=<SelectBackward>)
# tensor(249374.1719, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4165]) tensor([4475.]) tensor([3975.6199], grad_fn=<SelectBackward>)
# tensor(249380.5156, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7568]) tensor([4480.]) tensor([3980.6138], grad_fn=<SelectBackward>)
# tensor(249386.6094, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.9956]) tensor([4485.]) tensor([3985.6077], grad_fn=<SelectBackward>)
# tensor(249392.7031, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0950]) tensor([4490.]) tensor([3990.6016], grad_fn=<SelectBackward>)
# tensor(249398.7969, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2696]) tensor([4495.]) tensor([3995.5955], grad_fn=<SelectBackward>)
# tensor(249404.8906, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3215]) tensor([4500.]) tensor([4000.5896], grad_fn=<SelectBackward>)
# tensor(249410.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4196]) tensor([4505.]) tensor([4005.5837], grad_fn=<SelectBackward>)
# tensor(249416.5938, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0586]) tensor([4510.]) tensor([4010.5779], grad_fn=<SelectBackward>)
# tensor(249422.4531, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1855]) tensor([4515.]) tensor([4015.5720], grad_fn=<SelectBackward>)
# tensor(249428.3125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2414]) tensor([4520.]) tensor([4020.5664], grad_fn=<SelectBackward>)
# tensor(249433.9219, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6291]) tensor([4525.]) tensor([4025.5608], grad_fn=<SelectBackward>)
# tensor(249439.5312, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0672]) tensor([4530.]) tensor([4030.5552], grad_fn=<SelectBackward>)
# tensor(249445.1250, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5787]) tensor([4535.]) tensor([4035.5496], grad_fn=<SelectBackward>)
# tensor(249450.7344, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0269]) tensor([4540.]) tensor([4040.5439], grad_fn=<SelectBackward>)
# tensor(249456.3438, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4384]) tensor([4545.]) tensor([4045.5386], grad_fn=<SelectBackward>)
# tensor(249461.7188, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3621]) tensor([4550.]) tensor([4050.5332], grad_fn=<SelectBackward>)
# tensor(249467.0781, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7488]) tensor([4555.]) tensor([4055.5278], grad_fn=<SelectBackward>)
# tensor(249472.4531, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9454]) tensor([4560.]) tensor([4060.5225], grad_fn=<SelectBackward>)
# tensor(249477.8125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4096]) tensor([4565.]) tensor([4065.5173], grad_fn=<SelectBackward>)
# tensor(249482.9375, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.1070]) tensor([4570.]) tensor([4070.5122], grad_fn=<SelectBackward>)
# tensor(249488.0625, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5538]) tensor([4575.]) tensor([4075.5071], grad_fn=<SelectBackward>)
# tensor(249493.1719, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6436]) tensor([4580.]) tensor([4080.5020], grad_fn=<SelectBackward>)
# tensor(249498.2969, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.3743]) tensor([4585.]) tensor([4085.4968], grad_fn=<SelectBackward>)
# tensor(249503.4219, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0264]) tensor([4590.]) tensor([4090.4919], grad_fn=<SelectBackward>)
# tensor(249508.2969, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2221]) tensor([4595.]) tensor([4095.4871], grad_fn=<SelectBackward>)
# tensor(249513.1719, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0556]) tensor([4600.]) tensor([4100.4824], grad_fn=<SelectBackward>)
# tensor(249517.8125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7448]) tensor([4605.]) tensor([4105.4775], grad_fn=<SelectBackward>)
# tensor(249522.6875, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5848]) tensor([4610.]) tensor([4110.4727], grad_fn=<SelectBackward>)
# tensor(249527.5625, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.1406]) tensor([4615.]) tensor([4115.4678], grad_fn=<SelectBackward>)
# tensor(249532.4531, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.3679]) tensor([4620.]) tensor([4120.4629], grad_fn=<SelectBackward>)
# tensor(249537.3281, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9369]) tensor([4625.]) tensor([4125.4585], grad_fn=<SelectBackward>)
# tensor(249541.7188, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2220]) tensor([4630.]) tensor([4130.4541], grad_fn=<SelectBackward>)
# tensor(249546.1094, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7281]) tensor([4635.]) tensor([4135.4497], grad_fn=<SelectBackward>)
# tensor(249550.5000, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6970]) tensor([4640.]) tensor([4140.4453], grad_fn=<SelectBackward>)
# tensor(249554.8906, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.1286]) tensor([4645.]) tensor([4145.4409], grad_fn=<SelectBackward>)
# tensor(249559.2812, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.9843]) tensor([4650.]) tensor([4150.4365], grad_fn=<SelectBackward>)
# tensor(249563.6719, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.8038]) tensor([4655.]) tensor([4155.4321], grad_fn=<SelectBackward>)
# tensor(249568.0625, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.9034]) tensor([4660.]) tensor([4160.4277], grad_fn=<SelectBackward>)
# tensor(249572.4531, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0912]) tensor([4665.]) tensor([4165.4233], grad_fn=<SelectBackward>)
# tensor(249576.8438, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6409]) tensor([4670.]) tensor([4170.4189], grad_fn=<SelectBackward>)
# tensor(249581.2344, grad_fn=<MseLossBackward>)
# .......................
# tensor([0.9653]) tensor([4675.]) tensor([4175.4146], grad_fn=<SelectBackward>)
# tensor(249585.6250, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0055]) tensor([4680.]) tensor([4180.4106], grad_fn=<SelectBackward>)
# tensor(249589.5312, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.8968]) tensor([4685.]) tensor([4185.4067], grad_fn=<SelectBackward>)
# tensor(249593.4219, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.2254]) tensor([4690.]) tensor([4190.4028], grad_fn=<SelectBackward>)
# tensor(249597.3281, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0941]) tensor([4695.]) tensor([4195.3989], grad_fn=<SelectBackward>)
# tensor(249601.2344, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5870]) tensor([4700.]) tensor([4200.3950], grad_fn=<SelectBackward>)
# tensor(249605.1406, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5095]) tensor([4705.]) tensor([4205.3911], grad_fn=<SelectBackward>)
# tensor(249609.0469, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5740]) tensor([4710.]) tensor([4210.3872], grad_fn=<SelectBackward>)
# tensor(249612.9375, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2137]) tensor([4715.]) tensor([4215.3833], grad_fn=<SelectBackward>)
# tensor(249616.8438, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.9229]) tensor([4720.]) tensor([4220.3794], grad_fn=<SelectBackward>)
# tensor(249620.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2875]) tensor([4725.]) tensor([4225.3755], grad_fn=<SelectBackward>)
# tensor(249624.6562, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7782]) tensor([4730.]) tensor([4230.3716], grad_fn=<SelectBackward>)
# tensor(249628.5625, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.4039]) tensor([4735.]) tensor([4235.3677], grad_fn=<SelectBackward>)
# tensor(249632.4531, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.4118]) tensor([4740.]) tensor([4240.3638], grad_fn=<SelectBackward>)
# tensor(249636.3594, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.9675]) tensor([4745.]) tensor([4245.3604], grad_fn=<SelectBackward>)
# tensor(249639.7812, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.4382]) tensor([4750.]) tensor([4250.3569], grad_fn=<SelectBackward>)
# tensor(249643.1875, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7263]) tensor([4755.]) tensor([4255.3535], grad_fn=<SelectBackward>)
# tensor(249646.6094, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6850]) tensor([4760.]) tensor([4260.3501], grad_fn=<SelectBackward>)
# tensor(249650.0312, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2492]) tensor([4765.]) tensor([4265.3467], grad_fn=<SelectBackward>)
# tensor(249653.4375, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.1664]) tensor([4770.]) tensor([4270.3433], grad_fn=<SelectBackward>)
# tensor(249656.8594, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.8830]) tensor([4775.]) tensor([4275.3398], grad_fn=<SelectBackward>)
# tensor(249660.2656, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3021]) tensor([4780.]) tensor([4280.3364], grad_fn=<SelectBackward>)
# tensor(249663.6875, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7476]) tensor([4785.]) tensor([4285.3330], grad_fn=<SelectBackward>)
# tensor(249667.1094, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2709]) tensor([4790.]) tensor([4290.3296], grad_fn=<SelectBackward>)
# tensor(249670.5156, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0156]) tensor([4795.]) tensor([4295.3262], grad_fn=<SelectBackward>)
# tensor(249673.9375, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0725]) tensor([4800.]) tensor([4300.3228], grad_fn=<SelectBackward>)
# tensor(249677.3438, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0820]) tensor([4805.]) tensor([4305.3193], grad_fn=<SelectBackward>)
# tensor(249680.7656, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0708]) tensor([4810.]) tensor([4310.3159], grad_fn=<SelectBackward>)
# tensor(249684.1875, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0645]) tensor([4815.]) tensor([4315.3130], grad_fn=<SelectBackward>)
# tensor(249687.1094, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5495]) tensor([4820.]) tensor([4320.3101], grad_fn=<SelectBackward>)
# tensor(249690.0312, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0191]) tensor([4825.]) tensor([4325.3071], grad_fn=<SelectBackward>)
# tensor(249692.9688, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.2310]) tensor([4830.]) tensor([4330.3042], grad_fn=<SelectBackward>)
# tensor(249695.8906, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7813]) tensor([4835.]) tensor([4335.3013], grad_fn=<SelectBackward>)
# tensor(249698.8281, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.4015]) tensor([4840.]) tensor([4340.2983], grad_fn=<SelectBackward>)
# tensor(249701.7500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0446]) tensor([4845.]) tensor([4345.2954], grad_fn=<SelectBackward>)
# tensor(249704.6719, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.9271]) tensor([4850.]) tensor([4350.2925], grad_fn=<SelectBackward>)
# tensor(249707.6094, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.0241]) tensor([4855.]) tensor([4355.2896], grad_fn=<SelectBackward>)
# tensor(249710.5312, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3923]) tensor([4860.]) tensor([4360.2866], grad_fn=<SelectBackward>)
# tensor(249713.4688, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.0516]) tensor([4865.]) tensor([4365.2837], grad_fn=<SelectBackward>)
# tensor(249716.3906, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.4153]) tensor([4870.]) tensor([4370.2808], grad_fn=<SelectBackward>)
# tensor(249719.3125, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.9081]) tensor([4875.]) tensor([4375.2778], grad_fn=<SelectBackward>)
# tensor(249722.2500, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1790]) tensor([4880.]) tensor([4380.2749], grad_fn=<SelectBackward>)
# tensor(249725.1719, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3628]) tensor([4885.]) tensor([4385.2720], grad_fn=<SelectBackward>)
# tensor(249728.0938, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6203]) tensor([4890.]) tensor([4390.2690], grad_fn=<SelectBackward>)
# tensor(249731.0312, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.4667]) tensor([4895.]) tensor([4395.2661], grad_fn=<SelectBackward>)
# tensor(249733.9531, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7226]) tensor([4900.]) tensor([4400.2637], grad_fn=<SelectBackward>)
# tensor(249736.3906, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.4396]) tensor([4905.]) tensor([4405.2612], grad_fn=<SelectBackward>)
# tensor(249738.8438, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.3430]) tensor([4910.]) tensor([4410.2588], grad_fn=<SelectBackward>)
# tensor(249741.2812, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2905]) tensor([4915.]) tensor([4415.2563], grad_fn=<SelectBackward>)
# tensor(249743.7188, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.3447]) tensor([4920.]) tensor([4420.2539], grad_fn=<SelectBackward>)
# tensor(249746.1562, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.8072]) tensor([4925.]) tensor([4425.2515], grad_fn=<SelectBackward>)
# tensor(249748.5938, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.8075]) tensor([4930.]) tensor([4430.2490], grad_fn=<SelectBackward>)
# tensor(249751.0312, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.4514]) tensor([4935.]) tensor([4435.2466], grad_fn=<SelectBackward>)
# tensor(249753.4844, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.6266]) tensor([4940.]) tensor([4440.2441], grad_fn=<SelectBackward>)
# tensor(249755.9219, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7620]) tensor([4945.]) tensor([4445.2417], grad_fn=<SelectBackward>)
# tensor(249758.3594, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.7987]) tensor([4950.]) tensor([4450.2393], grad_fn=<SelectBackward>)
# tensor(249760.7969, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.3395]) tensor([4955.]) tensor([4455.2368], grad_fn=<SelectBackward>)
# tensor(249763.2344, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.8890]) tensor([4960.]) tensor([4460.2344], grad_fn=<SelectBackward>)
# tensor(249765.6875, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.1775]) tensor([4965.]) tensor([4465.2319], grad_fn=<SelectBackward>)
# tensor(249768.1250, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2294]) tensor([4970.]) tensor([4470.2295], grad_fn=<SelectBackward>)
# tensor(249770.5625, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.1081]) tensor([4975.]) tensor([4475.2271], grad_fn=<SelectBackward>)
# tensor(249773., grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2511]) tensor([4980.]) tensor([4480.2246], grad_fn=<SelectBackward>)
# tensor(249775.4375, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.5491]) tensor([4985.]) tensor([4485.2222], grad_fn=<SelectBackward>)
# tensor(249777.8750, grad_fn=<MseLossBackward>)
# .......................
# tensor([2.1318]) tensor([4990.]) tensor([4490.2197], grad_fn=<SelectBackward>)
# tensor(249780.3281, grad_fn=<MseLossBackward>)
# .......................
# tensor([1.2519]) tensor([4995.]) tensor([4495.2178], grad_fn=<SelectBackward>)
# tensor(249782.2812, grad_fn=<MseLossBackward>)
# .......................
# tensor(249782.2812, grad_fn=<MseLossBackward>)
